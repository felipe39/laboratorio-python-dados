# %% [markdown]
# <a href="https://colab.research.google.com/github/felipe39/laboratorio-python-dados/blob/main/Variaveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
minha_idade = 31

# %%
minha_idade
# Out:
# 31

# %%
print('Eu tenho ', minha_idade, 'anos')
# Out:
# Eu tenho  31 anos

# %%
# A conversao da taxa para dolar
taxaUSD = 3.20
300 / taxaUSD
# Out:
# 93.75

# %%
#Use sempre variavel para numero ou texto sem misturar
meu_nome = 'ivan'

# %%
# Saber o tipo
type(taxaUSD)
# Out:
# float

# %%
type(meu_nome)
# Out:
# str

# %%
# Programa que armazena valor na variavel e depois mostra
print('O meu primeiro programa em python')
num1 = 100
num2 = 350
print('O resultado de', num1, '+', num2, 'é:',num1+num2)
print('Fim do program')
# Out:
# O meu primeiro programa em python
# O resultado de 100 + 350 é: 450
# Fim do program
